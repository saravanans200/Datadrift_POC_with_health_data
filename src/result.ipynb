# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import logging
from pathlib import Path
logging.basicConfig(filename="logs/log.txt",format='%(asctime)s %(message)s', filemode='w')
logger=logging.getLogger() 

#Now we are going to Set the threshold of logger to DEBUG 
logger.setLevel(logging.DEBUG)

# %%
def csv_path(csv):
    path = Path.cwd()
    path = str(path)
    path = path[:-4]
    path = path + csv
    f_path = str(Path(path))
    return f_path

# %%
result_data = pd.read_csv(csv_path('//artifact//result//result.csv'))
print(result_data)
# Out:
#                  Date_and_time  Logistic  DecisionTree  RandomForest   Xgboost
# 0   2023-12-14 12:00:49.534434  0.370000      0.240000         0.300  0.870000
# 1   2023-12-14 12:19:13.420462  0.370000      0.240000         0.300  0.870000
# 2   2023-12-14 12:19:23.767023  0.370000      0.240000         0.300  0.870000
# 3   2023-12-14 12:21:06.974868  0.370000      0.240000         0.300  0.870000
# 4   2023-12-14 12:22:22.942734  0.370000      0.240000         0.300  0.870000
# 5   2023-12-14 12:22:34.246466  0.370000      0.240000         0.300  0.870000
# 6   2023-12-14 13:29:47.873940  0.329143      0.803429         0.884  0.873143
# 7   2023-12-14 14:16:17.315336  0.338143      0.803000         0.884  0.873143
# 8   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 9   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 10  2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# ...

# %%
logger.info("2 python file import started") 
# %run src/Datadrift.ipynb
print("EDA process done")
# %run src/decisionTree.ipynb
print("decision tree done")
# %run src/randomForest.ipynb
print("random Forest done")
# %run src/logisticRegression.ipynb
print("logistic Regression done")
# %run src/xgboostbefore.ipynb
print("xgboost done")
# %run src/drift_detection.ipynb
print("drift detection")
logger.info("2 python file import ended")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\A4647\AppData\Local\anaconda3\lib\site-packages\IPython\core\magics\execution.py:697, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     696     fpath = arg_lst[0]
# --> 697     filename = file_finder(fpath)
#     698 except IndexError as e:
#
# File c:\Users\A4647\AppData\Local\anaconda3\lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'src/Datadrift.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 logger.info("2 python file import started")
# ----> 2 get_ipython().run_line_magic('run', 'src/Datadrift.ipynb')
# ...

# %%
logger.info("2 python file import started") 
# %run Datadrift.ipynb
print("EDA process done")
# %run decisionTree.ipynb
print("decision tree done")
# %run randomForest.ipynb
print("random Forest done")
# %run logisticRegression.ipynb
print("logistic Regression done")
# %run xgboostbefore.ipynb
print("xgboost done")
# %run drift_detection.ipynb
print("drift detection")
logger.info("2 python file import ended")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
rf_accuracy_score
dt_accuracy_score
lr_accuracy_score
xg_accuracy_score
# Out:
# 0.8731428571428571

# %% [markdown]
# rf_accuracy_score = 0.30
# dt_accuracy_score = 0.24
# lr_accuracy_score = 0.37
# xg_accuracy_score = 0.87

# %%
current = datetime.datetime.now()
print(current)
# Out:
# 2023-12-15 15:25:54.456050

# %%
result_data
# Out:
#                  Date_and_time  Logistic  DecisionTree  RandomForest   Xgboost
# 0   2023-12-14 12:00:49.534434  0.370000      0.240000         0.300  0.870000
# 1   2023-12-14 12:19:13.420462  0.370000      0.240000         0.300  0.870000
# 2   2023-12-14 12:19:23.767023  0.370000      0.240000         0.300  0.870000
# 3   2023-12-14 12:21:06.974868  0.370000      0.240000         0.300  0.870000
# 4   2023-12-14 12:22:22.942734  0.370000      0.240000         0.300  0.870000
# 5   2023-12-14 12:22:34.246466  0.370000      0.240000         0.300  0.870000
# 6   2023-12-14 13:29:47.873940  0.329143      0.803429         0.884  0.873143
# 7   2023-12-14 14:16:17.315336  0.338143      0.803000         0.884  0.873143
# 8   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 9   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 10  2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# ...

# %%
data = [current, rf_accuracy_score, dt_accuracy_score, lr_accuracy_score, xg_accuracy_score]

new_row = {'Date_and_time': current, 'Logistic': lr_accuracy_score, 'DecisionTree': dt_accuracy_score, 'RandomForest': rf_accuracy_score,'Xgboost':xg_accuracy_score}

result_data = result_data.append(new_row, ignore_index=True)

# %%
result_data
# Out:
#                  Date_and_time  Logistic  DecisionTree  RandomForest   Xgboost
# 0   2023-12-14 12:00:49.534434  0.370000      0.240000         0.300  0.870000
# 1   2023-12-14 12:19:13.420462  0.370000      0.240000         0.300  0.870000
# 2   2023-12-14 12:19:23.767023  0.370000      0.240000         0.300  0.870000
# 3   2023-12-14 12:21:06.974868  0.370000      0.240000         0.300  0.870000
# 4   2023-12-14 12:22:22.942734  0.370000      0.240000         0.300  0.870000
# 5   2023-12-14 12:22:34.246466  0.370000      0.240000         0.300  0.870000
# 6   2023-12-14 13:29:47.873940  0.329143      0.803429         0.884  0.873143
# 7   2023-12-14 14:16:17.315336  0.338143      0.803000         0.884  0.873143
# 8   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 9   2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 10  2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# ...

# %%
result_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date_and_time  35 non-null     object
#  1   Logistic       35 non-null     float64
#  2   DecisionTree   35 non-null     float64
#  3   RandomForest   35 non-null     float64
#  4   Xgboost        35 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.5+ KB

# %%
result_data["Date_and_time"] = pd.to_datetime(result_data["Date_and_time"])

# %%
result_data
# Out:
#                 Date_and_time  Logistic  DecisionTree  RandomForest   Xgboost
# 0  2023-12-14 12:00:49.534434  0.370000      0.240000         0.300  0.870000
# 1  2023-12-14 12:19:13.420462  0.370000      0.240000         0.300  0.870000
# 2  2023-12-14 12:19:23.767023  0.370000      0.240000         0.300  0.870000
# 3  2023-12-14 12:21:06.974868  0.370000      0.240000         0.300  0.870000
# 4  2023-12-14 12:22:22.942734  0.370000      0.240000         0.300  0.870000
# 5  2023-12-14 12:22:34.246466  0.370000      0.240000         0.300  0.870000
# 6  2023-12-14 13:29:47.873940  0.329143      0.803429         0.884  0.873143
# 7  2023-12-14 14:16:17.315336  0.338143      0.803000         0.884  0.873143
# 8  2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 9  2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# 10 2023-12-14 14:41:47.150440  0.338143      0.803000         0.884  0.873143
# ...

# %%
plt.plot(result_data.Date_and_time, result_data.Logistic)
 
plt.plot(result_data.Date_and_time, result_data.DecisionTree, color='green')

plt.plot(result_data.Date_and_time, result_data.Xgboost, color='red')

plt.plot(result_data.Date_and_time, result_data.RandomForest, color='yellow')
 
# Giving title to the graph
plt.title('model testing')
 
# rotating the x-axis tick labels at 30degree 
# towards right
plt.xticks(rotation=30, ha='right')
 
# Giving x and y label to the graph
plt.xlabel('Date')
plt.ylabel('models')
# Out:
# Text(0, 0.5, 'models')

# %%
#result_data.to_csv('C:/Users/A4647/OneDrive - Axtria/Desktop/Datadrift/Datadrift_POC_with_health_data/artifact/result/result.csv',index=False)
result_data.to_csv(csv_path('//artifact//result//result.csv'))
